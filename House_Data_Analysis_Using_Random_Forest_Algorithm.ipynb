# %% [markdown]
# <a href="https://colab.research.google.com/github/R329aghav/Raghavjr/blob/main/House_Data_Analysis_Using_Random_Forest_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/DATASETS/bangalore house price prediction OHE-data.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(path)

# %%
data.head()
# Out:
#    bath  balcony  ...  location_Mahadevpura  location_Tumkur Road
# 0     3      2.0  ...                     0                     0
# 1     3      3.0  ...                     0                     0
# 2     3      2.0  ...                     0                     0
# 3     2      2.0  ...                     0                     0
# 4     2      2.0  ...                     0                     0
#
# [5 rows x 108 columns]

# %%
data.tail()
# Out:
#       bath  balcony  ...  location_Mahadevpura  location_Tumkur Road
# 7115     3      2.0  ...                     0                     0
# 7116     3      1.0  ...                     0                     0
# 7117     2      1.0  ...                     0                     0
# 7118     2      1.0  ...                     0                     0
# 7119     2      1.0  ...                     0                     0
#
# [5 rows x 108 columns]

# %%
data.describe()
# Out:
#               bath      balcony  ...  location_Mahadevpura  location_Tumkur Road
# count  7120.000000  7120.000000  ...           7120.000000           7120.000000
# mean      2.390871     1.572759  ...              0.002809              0.002809
# std       0.876822     0.770583  ...              0.052929              0.052929
# min       1.000000     0.000000  ...              0.000000              0.000000
# 25%       2.000000     1.000000  ...              0.000000              0.000000
# 50%       2.000000     2.000000  ...              0.000000              0.000000
# 75%       3.000000     2.000000  ...              0.000000              0.000000
# max       9.000000     3.000000  ...              1.000000              1.000000
#
# [8 rows x 108 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Columns: 108 entries, bath to location_Tumkur Road
# dtypes: float64(4), int64(104)
# memory usage: 5.9 MB

# %%
data.shape
# Out:
# (7120, 108)

# %%
X=data.drop(['price'],axis=1).values
y=data['price']

# %%
print("X_shape-->",X.shape)
print("y_shape-->",y.shape)
# Out:
# X_shape--> (7120, 107)
# y_shape--> (7120,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print("X_train_shape-->",X_train.shape)
print("X_train_shape-->",X_train.shape)
print("y_train_shape-->",y_train.shape)
print("y_test_shape-->",y_test.shape)
# Out:
# X_train_shape--> (5696, 107)
# X_train_shape--> (5696, 107)
# y_train_shape--> (5696,)
# y_test_shape--> (1424,)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_100=RandomForestRegressor(n_estimators=200,criterion='mse')
regressor_100.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
regressor_100.score(X_test,y_test)
# Out:
# 0.953385801839219

# %%
predicted=regressor_100.predict(X_test)

# %%
print(predicted)
# Out:
# [ 68.7775   36.1221   60.43795 ...  89.4036   74.7915  853.24   ]

# %%
dataframe=pd.DataFrame(y_test,predicted)

# %%
print(dataframe)
# Out:
#             price
# 68.777500     NaN
# 36.122100     NaN
# 60.437950     NaN
# 85.101700     NaN
# 63.953850     NaN
# ...           ...
# 185.460000    NaN
# 55.191525     NaN
# 89.403600     NaN
# 74.791500     NaN
# 853.240000    NaN
#
# [1424 rows x 1 columns]

# %%
dataframe=pd.DataFrame({'Actual':y_test,'predict':predicted})
print(dataframe)
# Out:
#       Actual     predict
# 1189    68.0   68.777500
# 5876    36.0   36.122100
# 5597    61.0   60.437950
# 3391    85.0   85.101700
# 6122    64.0   63.953850
# ...      ...         ...
# 5830   187.0  185.460000
# 4887    57.0   55.191525
# 1861    90.0   89.403600
# 3014    75.0   74.791500
# 1670   864.0  853.240000
#
# [1424 rows x 2 columns]

# %%
dataframe.head()
# Out:
#       Actual   predict
# 1189    68.0  68.77750
# 5876    36.0  36.12210
# 5597    61.0  60.43795
# 3391    85.0  85.10170
# 6122    64.0  63.95385

# %%
graph=dataframe.head(20)

# %%
graph.plot(kind='bar')

# %%
import math
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,predicted)

# %%
print(mse)
# Out:
# 591.8534001696933

# %%
rmse=np.sqrt(mse)

# %%
print(rmse)
# Out:
# 24.328037326707907
